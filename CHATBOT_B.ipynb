# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushant018-sk/AD_03/blob/main/CHATBOT_B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import requests
from bs4 import BeautifulSoup
import google.generativeai as genai
from pypdf import PdfReader

genai.configure(api_key="AIzaSyDGqhD4inXskRb0b5iU-XwrPsZqq2PralU")

def scrape_website(url):
    try:
        headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"
        }
        response = requests.get(url, headers=headers, timeout=10)

        if response.status_code != 200:
            print("Website blocked or unavailable")
            return ""

        soup = BeautifulSoup(response.text, "html.parser")
        paragraphs = soup.find_all("p")

        text = " ".join(p.get_text(strip=True) for p in paragraphs)

        return text[:5000]

    except Exception as e:
        print("Website error:", e)
        return ""

def read_pdf(file_path):
    text = ""
    try:
        reader = PdfReader(file_path)
        for page in reader.pages:
            extracted = page.extract_text()
            if extracted:
                text += extracted + "\n"
    except Exception as e:
        print("PDF error:", e)
    return text

def ai_answer(question, manual_text, web_text):
    model = genai.GenerativeModel("gemini-2.5-flash")

    prompt = f"""
Use ONLY the text below to answer.
If not found, say:
"This information is not available."

PDF Text:
{manual_text}

Website Text:
{web_text}

Question:
{question}
"""

    response = model.generate_content(prompt)
    return response.text.strip()

web_text = scrape_website("https://en.wikipedia.org/wiki/Narendra_Modi")
manual_text = read_pdf("/content/CN_LAB_2330051.pdf")

print("Help Bot is ready")
print("Type 'exit' to quit.\n")

print("Website text preview:\n", web_text[:500])
print("\nPDF text preview:\n", manual_text[:500])

while True:
    user_input = input("You: ")
    if user_input.lower() == "exit":
        print("Bot: Goodbye!")
        break

    reply = ai_answer(user_input, manual_text, web_text)
    print("\nBot:", reply, "\n")
# Out:
# Help Bot is ready
# Type 'exit' to quit.
#
# Website text preview:
#   Chief Ministership Premiership(Timeline) Budgets Constitutional amendments Campaigns Missions Establishments and foundations Events and observances Military and rescue operations Treaties and accords Establishments and foundations Events and observances Military and rescue operations Treaties and accords Narendra Damodardas Modi[a](born 17 September 1950) is an Indian politician who has served as theprime minister of Indiasince 2014. Modi was thechief minister of Gujaratfrom 2001 to 2014 and is
#
# PDF text preview:
#  EXPERIMENT - 1
# Aim: To explore various applications using Wireshark protocol analyzer and to analyze how the TCP/IP
# stack works.
# Software/Hardware Required: Wireshark Protocol Analyzer, System with Internet connection
# Theory: Wireshark is a network protocol analyzer used to capture and inspect data packets traveling
# ...
